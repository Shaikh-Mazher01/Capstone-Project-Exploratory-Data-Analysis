# %% [markdown]
# # **Project Name**    -  **Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# <!-- ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -** -->

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Hotel Booking Analysis**
#
# As in todays world there are many people who are willing to book a hotel because of the vacations and many more reasons. So here we are to analysis the data by knowing the maximum booking in which days weekdays or weekends. For how long the people stay in hotel. Which agents are providing more customers? How much children arrives in hotel till now? and many more data analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shaikh-Mazher01/Capstone-Project-Exploratory-Data-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# We are here to analysis the data based on city hotel and resort hotel. We have dataset from where we have to evaluate the revenue of hotel, maximum stay night in hotel, Which country is more active in booking in hotel,etc.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Which is the target audience for the hotel? Which hotel has more revenue? In which season the maximum booking? how was profit or loss graph.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path='/content/drive/MyDrive/Data_Science/Hotel Bookings.csv'
df=pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# My dataset contain 119390 rows and 32 columns with 31994 duplicate values and it also contain the null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The columns and the data it represents are listed below:
#
# 1.   hotel : Name of the hotel
# 2.   is_canceled : If the booking was canceled (1) or not (0)
# 3.   lead_time : Number of days before the actual arrival of the guests
# 4.   arrival_date_year : Year of arrival
# 5.   arrival_date_month : Month of arrival
# 6.   arrival_date_week_number : Week number of year for arrival
# 7.   arrival_date_day_of_month : Arrival date
# 8.   stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
# 9.   stays_in_week_nights : Number of weeknights (Monday to Friday) spent at the hotel by the guests.
# 10.   adults : Number of adults among guests
# 11.   children : Number of children among guests
# 12.   babies : Number of babies among guests
# 13.   meal : Type of meal booked
# 14.   country : Country of guests
# 15.   market_segment : Designation of market segment
# 16.  distribution_channel : Name of booking distribution channel
# 17.  is_repeated_guest : If the booking was from a repeated guest (1) or not (0)
# 18.   previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
# 19.   previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
# 20.   reserved_room_type : Code of room type reserved
# 21.   assigned_room_type : Code of room type assigned
# 22.   booking_changes : Number of changes/amendments made to the booking
# 23.   deposit_type : Type of the deposit made by the guest
# 24.   agent : ID of travel agent who made the booking
# 25.   company : ID of the company that made the booking
# 26.   days_in_waiting_list : Number of days the booking was in the waiting list
# 27.   customer_type : Type of customer, assuming one of four categories
# 28.   adr : Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
# 29.   required_car_parking_spaces : Number of car parking spaces required by the customer
# 30.   total_of_special_requests : Number of special requests made by the customer
# 31.   reservation_status : Reservation status (Canceled, Check-Out or No-Show)
# 32.   reservation_status_date : Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %%
df.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df[['company','agent']] = df[['company','agent']].fillna(0)

# %%
df.isna().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           452
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# ...

# %%
missing_value=df.isnull().sum().sort_values(ascending = False)
print(missing_value[:4])
# Out:
# country     452
# children      4
# hotel         0
# agent         0
# dtype: int64

# %%
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
df['country'].fillna('others', inplace = True)

# %%
df[df['adults']+df['children']+df['babies']==0].shape
# Out:
# (166, 32)

# %%
df.drop(df[df['adults']+df['children']+df['babies']==0].index,inplace=True)

# %%
df.shape
# Out:
# (87230, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87230 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87230 non-null  object
#  1   is_canceled                     87230 non-null  int64
#  2   lead_time                       87230 non-null  int64
#  3   arrival_date_year               87230 non-null  int64
#  4   arrival_date_month              87230 non-null  object
#  5   arrival_date_week_number        87230 non-null  int64
#  6   arrival_date_day_of_month       87230 non-null  int64
#  7   stays_in_weekend_nights         87230 non-null  int64
#  8   stays_in_week_nights            87230 non-null  int64
#  9   adults                          87230 non-null  int64
#  10  children                        87230 non-null  float64
#  11  babies                          87230 non-null  int64
# ...

# %%
df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %%
df['total_stay'] = df['stays_in_weekend_nights']+df['stays_in_week_nights']
df['total_people'] = df['adults']+df['children']+df['babies']

# %%
df.shape
# Out:
# (87230, 34)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Firstly I have dropped all the duplicate rows from the data. Then saw the null values in the rows as I found null values in four columns. I removed all the null rows to zero whose company and agents are null. In Children column I replaced the null values with the mean of children. In Country column i have put the other by replacing null. Some rows has 0 child 0 adult and 0 babies so I dropped all that rows. I have changed the data type for the required columns. and lastly i maked two more columns as total_stay and total_people for more clarification.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####Chart 1- Agent booked hotel.

# %%
# Chart - 1 visualization code
d1 = pd.DataFrame(df['agent'].value_counts()).reset_index().rename(columns = {'index':'agent','agent':'num_of_bookings'}).sort_values(by = 'num_of_bookings', ascending = False)
d1.drop(d1[d1['agent'] == 0].index, inplace = True)
d1 = d1[:20]
plt.figure(figsize = (12,6))
sns.barplot(x = 'agent', y = 'num_of_bookings', data = d1, order = d1.sort_values('num_of_bookings', ascending = False).agent)
#print(df['agent'].value_counts().iloc[0])
# Out:
# <Axes: xlabel='agent', ylabel='num_of_bookings'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is used to check the no. of booking by the agents and which agent make booking most in count of 20.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Using this bar chart we can see that the agent 9 booked the hotel 28721 times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes agent 9 is booking the highest rooms and more trustworthy .

# %% [markdown]
# By knowing that we can say that agent having more booking in hotel is trustworthy.

# %% [markdown]
# #### Chart 2- Demanded Rooms

# %%
# Chart - 2 visualization code
fig, axes = plt.subplots(1, 1, figsize=(12,6))

grp_by_room = df.groupby('assigned_room_type')

sns.countplot(x = df['assigned_room_type'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is used to see the highly demanded rooms.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart we can see that A is high demanded room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Only A and D rooms are demanded where other room has to advertise more.

# %% [markdown]
# We have to check the cost to for the room which is demanded.

# %% [markdown]
# #### Chart - 3 Country booked chart

# %%
# Chart - 3 visualization code
grp_by_country = df.groupby('country')
plt.figure(figsize = (12,6))
d2 = pd.DataFrame(grp_by_country.size()).rename(columns = {0:'no. of bookings'}).sort_values('no. of bookings', ascending = False)
d2 = d2[:10]
sns.barplot(x = d2.index, y = d2['no. of bookings'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see which country visited maximum time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# PRT is the country who visited maximum number of time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes we gained the positive business impact from this data.

# %% [markdown]
# #### Chart - 4 Hotel boooking

# %%
# Chart - 4 visualization code
grouped_by_hotel = df.groupby('hotel')
d1 = pd.DataFrame((grouped_by_hotel.size()/df.shape[0])*100).reset_index().rename(columns = {0:'Booking %'})
plt.figure(figsize = (12,6))
sns.barplot(x = d1['hotel'], y = d1['Booking %'] )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to see which hotel booking is most.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that City Hotel booking is more than the Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it is a positive business impact.

# %% [markdown]
# #### Chart - 5 Hotel Cancellation

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12,6))
sns.countplot(data=df,x='hotel',hue='is_canceled', palette='Greens',)
plt.legend(['Not Cancelled', 'Cancelled'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check where is cancellation ratio in city hotel and resort hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has more booked rooms as compared to resort hotel and cancellation too, but ratio of cancelled and not cancelled is more in city hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City Hotel is more favorite or suggestable by the customers.

# %% [markdown]
# #### Chart - 6 Average daily rate vs total stay

# %%
# Chart - 6 visualization code
plt.figure(figsize = (12,6))
sns.stripplot(y = 'adr', x = 'total_stay',hue='hotel',palette='YlOrRd', data = df)
plt.xlabel("Total stay in hotel")
plt.ylim((0,500))
# Out:
# (0.0, 500.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check an average daily rate vs total stay in both the hotels and we saw that adr is decreasing as total stay is increasing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  We saw that adr is decreasing as total stay is increasing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows that price is resonable for the longer stay customers.

# %% [markdown]
# #### Chart - 7 Revenue by distribution channel

# %%
# Chart - 7 visualization code
group_by_dc_hotel = df.groupby(['distribution_channel', 'hotel'])
d5 = pd.DataFrame(round((group_by_dc_hotel['adr']).agg(np.mean),2)).reset_index().rename(columns = {'adr': 'avg_adr'})
plt.figure(figsize = (12,6))
sns.barplot(x = d5['distribution_channel'], y = d5['avg_adr'], hue = d5['hotel'])
plt.ylim(40,140)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check distribution channel makes more revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# GDS channel brings higher revenue generating deals for City hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City hotel make more revenue with distribution channel whereas Resort hotel needs to make more revenue.

# %% [markdown]
# #### Chart - 8 Affect of cancellation

# %%
# Chart - 8 visualization code
waiting_bookings = df[df['days_in_waiting_list'] !=0]  # Selecting bookings with non zero waiting time


fig, axes = plt.subplots(1, 2, figsize=(18, 8))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings)
sns.kdeplot(ax = axes[1], x = df['lead_time'], hue = df['is_canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# longer waiting period or longer lead time causes the cancellation of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that most of the bookings that are cancelled have waiting period of less 150 days but also most of bookings that are not cancelled also have waiting period less than 150 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Lead time has no affect on cancellation of bookings,

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
df_pie = df.groupby(['meal']).agg({'hotel':'count'}).reset_index()
colors = sns.color_palette('bright')[0:5]
plt.figure(figsize=(12,6))
plt.pie(df_pie['hotel'], labels = df_pie.meal , colors = colors, autopct='%.0f%%')
plt.title('Percentage of meal booking')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check meal booked in hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BB type of food is more ordered than any other type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 78% of customers are booking BB type of food whereas only 22% is booked by other type.

# %% [markdown]
# #### Chart - 10 Market segment of hotels

# %%
# Chart - 10 visualization code
plt.figure(figsize = (12,6))
ax = sns.countplot(x = 'market_segment',palette='Accent',data=df,hue='hotel',legend=True)
ax.set_xlabel('market segment')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check which market segment is more.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Online TA is more used for booking hotel in both city hotel and resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we can see that Online marketing is more than any other of market segment.

# %% [markdown]
# #### Chart - 11 Waiting list

# %%
# Chart - 11 visualization code
plt.figure(figsize = (12,6))
ax = sns.stripplot(x = 'market_segment', y = 'days_in_waiting_list',palette='Accent',data=df, hue='hotel')
ax.set_xlabel('Market segment', fontsize = 20)
ax.set_ylabel('Days in waiting list', fontsize = 20)
ax.set_title('Days in waiting list by market segment', fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know the waiting period by market segment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Offline TA/To has more waiting time and aviation has less waiting time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# More waiting time in offline suggest customer to not book hotel directly.

# %% [markdown]
# #### Chart - 12 Reserved rooms

# %%
# Chart - 12 visualization code
plt.figure(figsize = (12,6))
ax = sns.countplot(x = 'reservation_status',hue='hotel' ,palette='Paired',data=df)
ax.set_xlabel('Reservation status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the cancelled and check out status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# more number of people check out from hotel an some cancelled the booking and few of them are still to be cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# More guest are joining in our hotel.

# %% [markdown]
# #### Chart - 13 Type of customers

# %%
# Chart - 13 visualization code
plt.figure(figsize = (12,6))
ax = sns.countplot(x = 'customer_type' ,data=df,palette='Set3',hue='hotel',order=sorted(df['customer_type'].unique()))
ax.set_xlabel('Customer type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check which customer type is most.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient type of customers are booking hotel more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Group are coming less in both the hotels and transient are comes more.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
d = df[['previous_cancellations','previous_bookings_not_canceled','lead_time','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests']]
co_relation_matrix = d.corr()
f, ax = plt.subplots(figsize=(14,10))
sns.heatmap(co_relation_matrix, fmt='.2f',cmap='coolwarm',annot = True, annot_kws={'size': 12},  vmax = .9 )
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the correlation between selected columns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Booking not cancelled is more than previously cancelled.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
pp=df[['previous_cancellations','previous_bookings_not_canceled','lead_time','total_stay']]
sns.pairplot(pp)
plt.show()

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# People came to resort hotel and city hotel for visiting the places near the location. The stay at the hotel only for the night purpose and one of the meal as I analysis that BB (bed and breakfast) are the more aquarired by the hotel. As the other like half board and no meal are about 22% which means people comes only for the sleep purpose to hotel and least people are come to enjoy the life away from the relative or families. I suggest the client to make more advertisement to the other rooms and make inspire the other agent to work and give more customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# City hotel has more number of booking as comapred to the Resort hotel. Hotel booking from year 2016 is increaing more rapidly and the season of may to august is the busiest season for booking. November to February are least reservation months.There is more special request in summer season. Around 77% of people are booking for BB (bed and breakfast) and other are nearly 23%. In market segment  TA/TO are mostly used by the people for travelling.There is more demand for room A which is booking more in number. As There is more waiting list which can say that there more demand for our hotels.Transient type of customers are more in the hotel. Cancellation of booking not affect waiting time or lead time which is more positive imapct as business objective.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
